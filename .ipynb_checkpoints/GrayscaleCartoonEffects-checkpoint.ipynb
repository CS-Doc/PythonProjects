# %% [markdown]
# # Importing necessary libraries

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# # Read/Display an Image

# %%
image_color = mpimg.imread("Ho_Ho_Horse.jpg")

# %%
plt.imshow(image_color)

# %%
image_color.shape
# Out:
# (2322, 4128, 3)

# %% [markdown]
# # Convert an image into grayscale

# %%
image_gray = cv2.cvtColor(image_color, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray, cmap = 'gray')

# %%
image_gray.shape
# Out:
# (2322, 4128)

# %%
image_gray
# Out:
# array([[ 11,  12,  17, ..., 153, 152, 152],
#        [ 11,  14,  14, ..., 153, 153, 152],
#        [ 12,  14,  14, ..., 155, 155, 152],
#        ...,
#        [255, 255, 255, ..., 170, 178, 176],
#        [255, 255, 255, ..., 174, 176, 176],
#        [255, 255, 255, ..., 175, 176, 175]], dtype=uint8)

# %% [markdown]
# # Save the Grayscale image

# %%
cv2.imwrite("grayscale_ho_ho_horse.jpg", image_gray)
# Out:
# True

# %% [markdown]
# # Cartoon Effect

# %%
color_image = cv2.imread("Ho_Ho_Horse.jpg")
#cartoon_image = cv2.stylization(color_image, sigma_s=200, sigma_r=0.3)
cartoon_image, cartoon_image2 = cv2.pencilSketch(color_image, sigma_s=60, sigma_r=0.1)

# %%
cv2.imshow('cartoon', cartoon_image)
cv2.waitKey()
cv2.destroyAllWindows()
